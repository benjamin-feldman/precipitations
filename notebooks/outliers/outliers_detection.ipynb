# %%
import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns
import io
import os
import random as rd
import csv
from scipy.signal import convolve2d, convolve
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_13928\2904952402.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Fonction utilitaires :

def export_list_to_csv(data, file_name):
    csv_file_path = file_name + ".csv"
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object
        csv_writer = csv.writer(csvfile)
        
        # Write each sublist as a row in the CSV file
        for sublist in data:
            csv_writer.writerow(sublist)


def csv_to_list(csv_file_path):
    data_list = []
    with open(csv_file_path, mode='r') as file:
        csv_reader = csv.reader(file)
        
        for row in csv_reader:
            row_list = [[int(num) for num in string.strip('[]').split()] for string in row]
            data_list.append(row_list)
    return data_list

# %%
# Test de détection d'outliers

def outlier_final(array):
    length = array.shape[0]
    L = []
    kernel = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
    
    # Accumulation sur 4 heures 
    data_4_hours = np.array([np.sum(array[48 * i:48 * (i + 1)], axis=0) for i in range(length // 48)])
    

    S = np.array([convolve2d(element, kernel, mode='same') for element in data_4_hours])
    
    for t in range(len(S)):
        St = S[t]
        Dt = data_4_hours[t]
        frontier_Dt = np.mean(Dt) + 5 * np.std(Dt)
        frontier_St = np.mean(St) + 30 * np.std(St)
        
        A = np.argwhere((np.abs(St) > frontier_St) & (np.abs(Dt) > frontier_Dt))
        
        for _ in range(48):
            L.append(A)
            
    return L

# %%
zip_filename = 'outliers_per_days.zip'

with zipfile.ZipFile(zip_filename, 'w') as zipf:
    pass

# %%
zip_file_path = "data/2018.zip"

with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
        all_files = zip_ref.namelist()
        for file in all_files:
            if file.endswith(".npy"):
                year_month_day = file[19:27]
                print(year_month_day)
                with zip_ref.open(file) as file_in_zip:
                    npy_bytes = file_in_zip.read()
                    npy_file_like = io.BytesIO(npy_bytes)
                    npy_array = np.load(npy_file_like)
                    outlier_list = outlier_final(npy_array)
                    csv_data = io.StringIO()
                    writer = csv.writer(csv_data)
                    for row in outlier_list:
                        writer.writerow(row)

                    # Nom du fichier CSV dans le ZIP
                    csv_filename = f'outliers_{year_month_day}.csv'

                    # Nom du fichier ZIP existant
                    zip_filename = 'outliers_per_days.zip'

                    # Ajouter le fichier CSV au fichier ZIP
                    with zipfile.ZipFile(zip_filename, 'a') as zipf:
                        zipf.writestr(csv_filename, csv_data.getvalue())

                    print(f'Fichier {csv_filename} ajouté à {zip_filename}')
                
                    npy_file_like.close()
# Out:
# 20180324
# Fichier outliers_20180324.csv ajouté à outliers_per_days.zip
# 20180325
# Fichier outliers_20180325.csv ajouté à outliers_per_days.zip
# 20180326
# Fichier outliers_20180326.csv ajouté à outliers_per_days.zip
# 20180327
# Fichier outliers_20180327.csv ajouté à outliers_per_days.zip
# 20180328
# Fichier outliers_20180328.csv ajouté à outliers_per_days.zip
# 20180329
# Fichier outliers_20180329.csv ajouté à outliers_per_days.zip
# 20180330
# Fichier outliers_20180330.csv ajouté à outliers_per_days.zip
# 20180331
# Fichier outliers_20180331.csv ajouté à outliers_per_days.zip
# 20180401
# Fichier outliers_20180401.csv ajouté à outliers_per_days.zip
# 20180402
# Fichier outliers_20180402.csv ajouté à outliers_per_days.zip
# 20180403
# Fichier outliers_20180403.csv ajouté à outliers_per_days.zip
# 20180404
# Fichier outliers_20180404.csv ajouté à outliers_per_days.zip
# 20180405
# Fichier outliers_20180405.csv ajouté à outliers_per_days.zip
# 20180406
# Fichier outliers_20180406.csv ajouté à outliers_per_days.zip
# 20180407
# Fichier outliers_20180407.csv ajouté à outliers_per_days.zip
# 20180408
# Fichier outliers_20180408.csv ajouté à outliers_per_days.zip
# 20180409
# Fichier outliers_20180409.csv ajouté à outliers_per_days.zip
# 20180410
# Fichier outliers_20180410.csv ajouté à outliers_per_days.zip
# 20180411
# Fichier outliers_20180411.csv ajouté à outliers_per_days.zip
# 20180412
# Fichier outliers_20180412.csv ajouté à outliers_per_days.zip
# 20180413
# Fichier outliers_20180413.csv ajouté à outliers_per_days.zip
# 20180414
# Fichier outliers_20180414.csv ajouté à outliers_per_days.zip
# 20180415
# Fichier outliers_20180415.csv ajouté à outliers_per_days.zip
# 20180416
# Fichier outliers_20180416.csv ajouté à outliers_per_days.zip
# 20180417
# Fichier outliers_20180417.csv ajouté à outliers_per_days.zip
# 20180418
# Fichier outliers_20180418.csv ajouté à outliers_per_days.zip
# 20180419
# Fichier outliers_20180419.csv ajouté à outliers_per_days.zip
# 20180420
# Fichier outliers_20180420.csv ajouté à outliers_per_days.zip
# 20180421
# Fichier outliers_20180421.csv ajouté à outliers_per_days.zip
# 20180422
# Fichier outliers_20180422.csv ajouté à outliers_per_days.zip
# 20180423
# Fichier outliers_20180423.csv ajouté à outliers_per_days.zip
# 20180424
# Fichier outliers_20180424.csv ajouté à outliers_per_days.zip
# 20180425
# Fichier outliers_20180425.csv ajouté à outliers_per_days.zip
# 20180426
# Fichier outliers_20180426.csv ajouté à outliers_per_days.zip
# 20180427
# Fichier outliers_20180427.csv ajouté à outliers_per_days.zip
# 20180428
# Fichier outliers_20180428.csv ajouté à outliers_per_days.zip
# 20180429
# Fichier outliers_20180429.csv ajouté à outliers_per_days.zip
# 20180430
# Fichier outliers_20180430.csv ajouté à outliers_per_days.zip
# 20180501
# Fichier outliers_20180501.csv ajouté à outliers_per_days.zip
# 20180502
# Fichier outliers_20180502.csv ajouté à outliers_per_days.zip
# 20180503
# Fichier outliers_20180503.csv ajouté à outliers_per_days.zip
# 20180504
# Fichier outliers_20180504.csv ajouté à outliers_per_days.zip
# 20180505
# Fichier outliers_20180505.csv ajouté à outliers_per_days.zip
# 20180506
# Fichier outliers_20180506.csv ajouté à outliers_per_days.zip
# 20180507
# Fichier outliers_20180507.csv ajouté à outliers_per_days.zip
# 20180508
# Fichier outliers_20180508.csv ajouté à outliers_per_days.zip
# 20180509
# Fichier outliers_20180509.csv ajouté à outliers_per_days.zip
# 20180510
# Fichier outliers_20180510.csv ajouté à outliers_per_days.zip
# 20180511
# Fichier outliers_20180511.csv ajouté à outliers_per_days.zip
# 20180512
# Fichier outliers_20180512.csv ajouté à outliers_per_days.zip
# 20180513
# Fichier outliers_20180513.csv ajouté à outliers_per_days.zip
# 20180514
# Fichier outliers_20180514.csv ajouté à outliers_per_days.zip
# 20180515
# Fichier outliers_20180515.csv ajouté à outliers_per_days.zip
# 20180516
# Fichier outliers_20180516.csv ajouté à outliers_per_days.zip
# 20180517
# Fichier outliers_20180517.csv ajouté à outliers_per_days.zip
# 20180518
# Fichier outliers_20180518.csv ajouté à outliers_per_days.zip
# 20180519
# Fichier outliers_20180519.csv ajouté à outliers_per_days.zip
# 20180520
# Fichier outliers_20180520.csv ajouté à outliers_per_days.zip
# 20180521
# Fichier outliers_20180521.csv ajouté à outliers_per_days.zip
# 20180522
# Fichier outliers_20180522.csv ajouté à outliers_per_days.zip
# 20180523
# Fichier outliers_20180523.csv ajouté à outliers_per_days.zip
# 20180524
# Fichier outliers_20180524.csv ajouté à outliers_per_days.zip
# 20180525
# Fichier outliers_20180525.csv ajouté à outliers_per_days.zip
# 20180526
# Fichier outliers_20180526.csv ajouté à outliers_per_days.zip
# 20180527
# Fichier outliers_20180527.csv ajouté à outliers_per_days.zip
# 20180528
# Fichier outliers_20180528.csv ajouté à outliers_per_days.zip
# 20180529
# Fichier outliers_20180529.csv ajouté à outliers_per_days.zip
# 20180530
# Fichier outliers_20180530.csv ajouté à outliers_per_days.zip
# 20180531
# Fichier outliers_20180531.csv ajouté à outliers_per_days.zip
# 20180601
# Fichier outliers_20180601.csv ajouté à outliers_per_days.zip
# 20180602
# Fichier outliers_20180602.csv ajouté à outliers_per_days.zip
# 20180603
# Fichier outliers_20180603.csv ajouté à outliers_per_days.zip
# 20180604
# Fichier outliers_20180604.csv ajouté à outliers_per_days.zip
# 20180605
# Fichier outliers_20180605.csv ajouté à outliers_per_days.zip
# 20180606
# Fichier outliers_20180606.csv ajouté à outliers_per_days.zip
# 20180607
# Fichier outliers_20180607.csv ajouté à outliers_per_days.zip
# 20180608
# Fichier outliers_20180608.csv ajouté à outliers_per_days.zip
# 20180609
# Fichier outliers_20180609.csv ajouté à outliers_per_days.zip
# 20180610
# Fichier outliers_20180610.csv ajouté à outliers_per_days.zip
# 20180611
# Fichier outliers_20180611.csv ajouté à outliers_per_days.zip
# 20180612
# Fichier outliers_20180612.csv ajouté à outliers_per_days.zip
# 20180613
# Fichier outliers_20180613.csv ajouté à outliers_per_days.zip
# 20180614
# Fichier outliers_20180614.csv ajouté à outliers_per_days.zip
# 20180615
# Fichier outliers_20180615.csv ajouté à outliers_per_days.zip
# 20180616
# Fichier outliers_20180616.csv ajouté à outliers_per_days.zip
# 20180617
# Fichier outliers_20180617.csv ajouté à outliers_per_days.zip
# 20180618
# Fichier outliers_20180618.csv ajouté à outliers_per_days.zip
# 20180619
# Fichier outliers_20180619.csv ajouté à outliers_per_days.zip
# 20180620
# Fichier outliers_20180620.csv ajouté à outliers_per_days.zip
# 20180621
# Fichier outliers_20180621.csv ajouté à outliers_per_days.zip
# 20180622
# Fichier outliers_20180622.csv ajouté à outliers_per_days.zip
# 20180623
# Fichier outliers_20180623.csv ajouté à outliers_per_days.zip
# 20180624
# Fichier outliers_20180624.csv ajouté à outliers_per_days.zip
# 20180625
# Fichier outliers_20180625.csv ajouté à outliers_per_days.zip
# 20180626
# Fichier outliers_20180626.csv ajouté à outliers_per_days.zip
# 20180627
# Fichier outliers_20180627.csv ajouté à outliers_per_days.zip
# 20180628
# Fichier outliers_20180628.csv ajouté à outliers_per_days.zip
# 20180629
# Fichier outliers_20180629.csv ajouté à outliers_per_days.zip
# 20180630
# Fichier outliers_20180630.csv ajouté à outliers_per_days.zip
# 20180701
# Fichier outliers_20180701.csv ajouté à outliers_per_days.zip
# 20180702
# Fichier outliers_20180702.csv ajouté à outliers_per_days.zip
# 20180703
# Fichier outliers_20180703.csv ajouté à outliers_per_days.zip
# 20180704
# Fichier outliers_20180704.csv ajouté à outliers_per_days.zip
# 20180705
# Fichier outliers_20180705.csv ajouté à outliers_per_days.zip
# 20180706
# Fichier outliers_20180706.csv ajouté à outliers_per_days.zip
# 20180707
# Fichier outliers_20180707.csv ajouté à outliers_per_days.zip
# 20180708
# Fichier outliers_20180708.csv ajouté à outliers_per_days.zip
# 20180709
# Fichier outliers_20180709.csv ajouté à outliers_per_days.zip
# 20180710
# Fichier outliers_20180710.csv ajouté à outliers_per_days.zip
# 20180711
# Fichier outliers_20180711.csv ajouté à outliers_per_days.zip
# 20180712
# Fichier outliers_20180712.csv ajouté à outliers_per_days.zip
# 20180713
# Fichier outliers_20180713.csv ajouté à outliers_per_days.zip
# 20180714
# Fichier outliers_20180714.csv ajouté à outliers_per_days.zip
# 20180715
# Fichier outliers_20180715.csv ajouté à outliers_per_days.zip
# 20180716
# Fichier outliers_20180716.csv ajouté à outliers_per_days.zip
# 20180717
# Fichier outliers_20180717.csv ajouté à outliers_per_days.zip
# 20180718
# Fichier outliers_20180718.csv ajouté à outliers_per_days.zip
# 20180719
# Fichier outliers_20180719.csv ajouté à outliers_per_days.zip
# 20180720
# Fichier outliers_20180720.csv ajouté à outliers_per_days.zip
# 20180721
# Fichier outliers_20180721.csv ajouté à outliers_per_days.zip
# 20180722
# Fichier outliers_20180722.csv ajouté à outliers_per_days.zip
# 20180723
# Fichier outliers_20180723.csv ajouté à outliers_per_days.zip
# 20180724
# Fichier outliers_20180724.csv ajouté à outliers_per_days.zip
# 20180725
# Fichier outliers_20180725.csv ajouté à outliers_per_days.zip
# 20180726
# Fichier outliers_20180726.csv ajouté à outliers_per_days.zip
# 20180727
# Fichier outliers_20180727.csv ajouté à outliers_per_days.zip
# 20180728
# Fichier outliers_20180728.csv ajouté à outliers_per_days.zip
# 20180729
# Fichier outliers_20180729.csv ajouté à outliers_per_days.zip
# 20180730
# Fichier outliers_20180730.csv ajouté à outliers_per_days.zip
# 20180731
# Fichier outliers_20180731.csv ajouté à outliers_per_days.zip
# 20180801
# Fichier outliers_20180801.csv ajouté à outliers_per_days.zip
# 20180802
# Fichier outliers_20180802.csv ajouté à outliers_per_days.zip
# 20180803
# Fichier outliers_20180803.csv ajouté à outliers_per_days.zip
# 20180804
# Fichier outliers_20180804.csv ajouté à outliers_per_days.zip
# 20180805
# Fichier outliers_20180805.csv ajouté à outliers_per_days.zip
# 20180806
# Fichier outliers_20180806.csv ajouté à outliers_per_days.zip
# 20180807
# Fichier outliers_20180807.csv ajouté à outliers_per_days.zip
# 20180808
# Fichier outliers_20180808.csv ajouté à outliers_per_days.zip
# 20180809
# Fichier outliers_20180809.csv ajouté à outliers_per_days.zip
# 20180810
# Fichier outliers_20180810.csv ajouté à outliers_per_days.zip
# 20180811
# Fichier outliers_20180811.csv ajouté à outliers_per_days.zip
# 20180812
# Fichier outliers_20180812.csv ajouté à outliers_per_days.zip
# 20180813
# Fichier outliers_20180813.csv ajouté à outliers_per_days.zip
# 20180814
# Fichier outliers_20180814.csv ajouté à outliers_per_days.zip
# 20180815
# Fichier outliers_20180815.csv ajouté à outliers_per_days.zip
# 20180816
# Fichier outliers_20180816.csv ajouté à outliers_per_days.zip
# 20180817
# Fichier outliers_20180817.csv ajouté à outliers_per_days.zip
# 20180818
# Fichier outliers_20180818.csv ajouté à outliers_per_days.zip
# 20180819
# Fichier outliers_20180819.csv ajouté à outliers_per_days.zip
# 20180820
# Fichier outliers_20180820.csv ajouté à outliers_per_days.zip
# 20180821
# Fichier outliers_20180821.csv ajouté à outliers_per_days.zip
# 20180822
# Fichier outliers_20180822.csv ajouté à outliers_per_days.zip
# 20180823
# Fichier outliers_20180823.csv ajouté à outliers_per_days.zip
# 20180824
# Fichier outliers_20180824.csv ajouté à outliers_per_days.zip
# 20180825
# Fichier outliers_20180825.csv ajouté à outliers_per_days.zip
# 20180826
# Fichier outliers_20180826.csv ajouté à outliers_per_days.zip
# 20180827
# Fichier outliers_20180827.csv ajouté à outliers_per_days.zip
# 20180828
# Fichier outliers_20180828.csv ajouté à outliers_per_days.zip
# 20180829
# Fichier outliers_20180829.csv ajouté à outliers_per_days.zip
# 20180830
# Fichier outliers_20180830.csv ajouté à outliers_per_days.zip
# 20180831
# Fichier outliers_20180831.csv ajouté à outliers_per_days.zip
# 20180901
# Fichier outliers_20180901.csv ajouté à outliers_per_days.zip
# 20180902
# Fichier outliers_20180902.csv ajouté à outliers_per_days.zip
# 20180903
# Fichier outliers_20180903.csv ajouté à outliers_per_days.zip
# 20180904
# Fichier outliers_20180904.csv ajouté à outliers_per_days.zip
# 20180905
# Fichier outliers_20180905.csv ajouté à outliers_per_days.zip
# 20180906
# Fichier outliers_20180906.csv ajouté à outliers_per_days.zip
# 20180907
# Fichier outliers_20180907.csv ajouté à outliers_per_days.zip
# 20180908
# Fichier outliers_20180908.csv ajouté à outliers_per_days.zip
# 20180909
# Fichier outliers_20180909.csv ajouté à outliers_per_days.zip
# 20180910
# Fichier outliers_20180910.csv ajouté à outliers_per_days.zip
# 20180911
# Fichier outliers_20180911.csv ajouté à outliers_per_days.zip
# 20180912
# Fichier outliers_20180912.csv ajouté à outliers_per_days.zip
# 20180913
# Fichier outliers_20180913.csv ajouté à outliers_per_days.zip
# 20180914
# Fichier outliers_20180914.csv ajouté à outliers_per_days.zip
# 20180915
# Fichier outliers_20180915.csv ajouté à outliers_per_days.zip
# 20180916
# Fichier outliers_20180916.csv ajouté à outliers_per_days.zip
# 20180917
# Fichier outliers_20180917.csv ajouté à outliers_per_days.zip
# 20180918
# Fichier outliers_20180918.csv ajouté à outliers_per_days.zip
# 20180919
# Fichier outliers_20180919.csv ajouté à outliers_per_days.zip
# 20180920
# Fichier outliers_20180920.csv ajouté à outliers_per_days.zip
# 20180921
# Fichier outliers_20180921.csv ajouté à outliers_per_days.zip
# 20180922
# Fichier outliers_20180922.csv ajouté à outliers_per_days.zip
# 20180923
# Fichier outliers_20180923.csv ajouté à outliers_per_days.zip
# 20180924
# Fichier outliers_20180924.csv ajouté à outliers_per_days.zip
# 20180925
# Fichier outliers_20180925.csv ajouté à outliers_per_days.zip
# 20180926
# Fichier outliers_20180926.csv ajouté à outliers_per_days.zip
# 20180927
# Fichier outliers_20180927.csv ajouté à outliers_per_days.zip
# 20180928
# Fichier outliers_20180928.csv ajouté à outliers_per_days.zip
# 20180929
# Fichier outliers_20180929.csv ajouté à outliers_per_days.zip
# 20180930
# Fichier outliers_20180930.csv ajouté à outliers_per_days.zip
# 20181001
# Fichier outliers_20181001.csv ajouté à outliers_per_days.zip
# 20181002
# Fichier outliers_20181002.csv ajouté à outliers_per_days.zip
# 20181003
# Fichier outliers_20181003.csv ajouté à outliers_per_days.zip
# 20181004
# Fichier outliers_20181004.csv ajouté à outliers_per_days.zip
# 20181005
# Fichier outliers_20181005.csv ajouté à outliers_per_days.zip
# 20181006
# Fichier outliers_20181006.csv ajouté à outliers_per_days.zip
# 20181007
# Fichier outliers_20181007.csv ajouté à outliers_per_days.zip
# 20181008
# Fichier outliers_20181008.csv ajouté à outliers_per_days.zip
# 20181009
# Fichier outliers_20181009.csv ajouté à outliers_per_days.zip
# 20181010
# Fichier outliers_20181010.csv ajouté à outliers_per_days.zip
# 20181011
# Fichier outliers_20181011.csv ajouté à outliers_per_days.zip
# 20181012
# Fichier outliers_20181012.csv ajouté à outliers_per_days.zip
# 20181013
# Fichier outliers_20181013.csv ajouté à outliers_per_days.zip
# 20181014
# Fichier outliers_20181014.csv ajouté à outliers_per_days.zip
# 20181015
# Fichier outliers_20181015.csv ajouté à outliers_per_days.zip
# 20181016
# Fichier outliers_20181016.csv ajouté à outliers_per_days.zip
# 20181017
# Fichier outliers_20181017.csv ajouté à outliers_per_days.zip
# 20181018
# Fichier outliers_20181018.csv ajouté à outliers_per_days.zip
# 20181019
# Fichier outliers_20181019.csv ajouté à outliers_per_days.zip
# 20181020
# Fichier outliers_20181020.csv ajouté à outliers_per_days.zip
# 20181021
# Fichier outliers_20181021.csv ajouté à outliers_per_days.zip
# 20181022
# Fichier outliers_20181022.csv ajouté à outliers_per_days.zip
# 20181023
# Fichier outliers_20181023.csv ajouté à outliers_per_days.zip
# 20181024
# Fichier outliers_20181024.csv ajouté à outliers_per_days.zip
# 20181025
# Fichier outliers_20181025.csv ajouté à outliers_per_days.zip
# 20181026
# Fichier outliers_20181026.csv ajouté à outliers_per_days.zip
# 20181027
# Fichier outliers_20181027.csv ajouté à outliers_per_days.zip
# 20181028
# Fichier outliers_20181028.csv ajouté à outliers_per_days.zip
# 20181029
# Fichier outliers_20181029.csv ajouté à outliers_per_days.zip
# 20181030
# Fichier outliers_20181030.csv ajouté à outliers_per_days.zip
# 20181031
# Fichier outliers_20181031.csv ajouté à outliers_per_days.zip
# 20181101
# Fichier outliers_20181101.csv ajouté à outliers_per_days.zip
# 20181102
# Fichier outliers_20181102.csv ajouté à outliers_per_days.zip
# 20181103
# Fichier outliers_20181103.csv ajouté à outliers_per_days.zip
# 20181104
# Fichier outliers_20181104.csv ajouté à outliers_per_days.zip
# 20181105
# Fichier outliers_20181105.csv ajouté à outliers_per_days.zip
# 20181106
# Fichier outliers_20181106.csv ajouté à outliers_per_days.zip
# 20181107
# Fichier outliers_20181107.csv ajouté à outliers_per_days.zip
# 20181108
# Fichier outliers_20181108.csv ajouté à outliers_per_days.zip
# 20181109
# Fichier outliers_20181109.csv ajouté à outliers_per_days.zip
# 20181110
# Fichier outliers_20181110.csv ajouté à outliers_per_days.zip
# 20181111
# Fichier outliers_20181111.csv ajouté à outliers_per_days.zip
# 20181112
# Fichier outliers_20181112.csv ajouté à outliers_per_days.zip
# 20181113
# Fichier outliers_20181113.csv ajouté à outliers_per_days.zip
# 20181114
# Fichier outliers_20181114.csv ajouté à outliers_per_days.zip
# 20181115
# Fichier outliers_20181115.csv ajouté à outliers_per_days.zip
# 20181116
# Fichier outliers_20181116.csv ajouté à outliers_per_days.zip
# 20181117
# Fichier outliers_20181117.csv ajouté à outliers_per_days.zip
# 20181118
# Fichier outliers_20181118.csv ajouté à outliers_per_days.zip
# 20181119
# Fichier outliers_20181119.csv ajouté à outliers_per_days.zip
# 20181120
# Fichier outliers_20181120.csv ajouté à outliers_per_days.zip
# 20181121
# Fichier outliers_20181121.csv ajouté à outliers_per_days.zip
# 20181122
# Fichier outliers_20181122.csv ajouté à outliers_per_days.zip
# 20181123
# Fichier outliers_20181123.csv ajouté à outliers_per_days.zip
# 20181124
# Fichier outliers_20181124.csv ajouté à outliers_per_days.zip
# 20181125
# Fichier outliers_20181125.csv ajouté à outliers_per_days.zip
# 20181126
# Fichier outliers_20181126.csv ajouté à outliers_per_days.zip
# 20181127
# Fichier outliers_20181127.csv ajouté à outliers_per_days.zip
# 20181128
# Fichier outliers_20181128.csv ajouté à outliers_per_days.zip
# 20181129
# Fichier outliers_20181129.csv ajouté à outliers_per_days.zip
# 20181130
# Fichier outliers_20181130.csv ajouté à outliers_per_days.zip
# 20181201
# Fichier outliers_20181201.csv ajouté à outliers_per_days.zip
# 20181202
# Fichier outliers_20181202.csv ajouté à outliers_per_days.zip
# 20181203
# Fichier outliers_20181203.csv ajouté à outliers_per_days.zip
# 20181204
# Fichier outliers_20181204.csv ajouté à outliers_per_days.zip
# 20181205
# Fichier outliers_20181205.csv ajouté à outliers_per_days.zip
# 20181206
# Fichier outliers_20181206.csv ajouté à outliers_per_days.zip
# 20181207
# Fichier outliers_20181207.csv ajouté à outliers_per_days.zip
# 20181208
# Fichier outliers_20181208.csv ajouté à outliers_per_days.zip
# 20181209
# Fichier outliers_20181209.csv ajouté à outliers_per_days.zip
# 20181210
# Fichier outliers_20181210.csv ajouté à outliers_per_days.zip
# 20181211
# Fichier outliers_20181211.csv ajouté à outliers_per_days.zip
# 20181212
# Fichier outliers_20181212.csv ajouté à outliers_per_days.zip
# 20181213
# Fichier outliers_20181213.csv ajouté à outliers_per_days.zip
# 20181214
# Fichier outliers_20181214.csv ajouté à outliers_per_days.zip
# 20181215
# Fichier outliers_20181215.csv ajouté à outliers_per_days.zip
# 20181216
# Fichier outliers_20181216.csv ajouté à outliers_per_days.zip
# 20181217
# Fichier outliers_20181217.csv ajouté à outliers_per_days.zip
# 20181218
# Fichier outliers_20181218.csv ajouté à outliers_per_days.zip
# 20181219
# Fichier outliers_20181219.csv ajouté à outliers_per_days.zip
# 20181220
# Fichier outliers_20181220.csv ajouté à outliers_per_days.zip
# 20181221
# Fichier outliers_20181221.csv ajouté à outliers_per_days.zip
# 20181222
# Fichier outliers_20181222.csv ajouté à outliers_per_days.zip
# 20181223
# Fichier outliers_20181223.csv ajouté à outliers_per_days.zip
# 20181224
# Fichier outliers_20181224.csv ajouté à outliers_per_days.zip
# 20181225
# Fichier outliers_20181225.csv ajouté à outliers_per_days.zip
# 20181226
# Fichier outliers_20181226.csv ajouté à outliers_per_days.zip
# 20181227
# Fichier outliers_20181227.csv ajouté à outliers_per_days.zip
# 20181228
# Fichier outliers_20181228.csv ajouté à outliers_per_days.zip
# 20181229
# Fichier outliers_20181229.csv ajouté à outliers_per_days.zip
# 20181230
# Fichier outliers_20181230.csv ajouté à outliers_per_days.zip
# 20181231
# Fichier outliers_20181231.csv ajouté à outliers_per_days.zip
